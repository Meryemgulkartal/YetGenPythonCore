# %% [markdown]
# # Problem 1
# Kullanıcıdan aldığı ürün bilgisini (ad, fiyat) urunler.txt dosyasına kayıt eden fonksiyonu yazınız.

# %%
ad = input("Ürünün adını giriniz:")
fiyat= float(input("Ürünün fiyatını giriniz:"))

file = open("urunler.txt", "w", encoding= "utf-8")
file.write(f"Ürünün adı: {ad}\nFiyatı: ${fiyat}")
file.close()

# %% [markdown]
# # Problem 2
# 1.problemde oluşturulan text dosyası içerisinde kullanıcıdan alacağımız eski kelime isimli değişkene atadığımız
# ve değiştirilmesini istediğimiz kelimemizi yerini alıcak olan yeni kelime isimli değişkene atayın. Belirlenen kelimeleri text dosyasında değiştiren fonksiyonu yazınız.

# %%
def kelimeDegistir(dosyaAdi ,eskiKelime, yeniKelime):
    with open(dosyaAdi, "r", encoding= "utf-8") as file:
        icerik = file.read()

    icerik2 = icerik.replace(eskiKelime, yeniKelime)

    with open(dosyaAdi, "r", encoding= "utf-8") as file:
        file.write(icerik2)

dosyaAdi = "urunler.txt"
eskiKelime = input("Eski kelimeyi girin:")
yeniKelime = input("Yeni kelimeyi girin:")

kelimeDegistir(dosyaAdi, eskiKelime, yeniKelime)
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# Cell In[4], line 14
#      11 eskiKelime = input("Eski kelimeyi girin:")
#      12 yeniKelime = input("Yeni kelimeyi girin:")
# ---> 14 kelimeDegistir(dosyaAdi, eskiKelime, yeniKelime)
#
# Cell In[4], line 8, in kelimeDegistir(dosyaAdi, eskiKelime, yeniKelime)
#       5 icerik2 = icerik.replace(eskiKelime, yeniKelime)
#       7 with open(dosyaAdi, "r", encoding= "utf-8") as file:
# ----> 8     file.write(icerik2)
#
# UnsupportedOperation: not writable

# %% [markdown]
# # Problem 3
# Vehicle sınıfının tüm değişkenlerini ve yöntemlerini devralacak bir alt sınıf olarak Bus sınıfı oluşturunuz.
#
#
#
# ```
# Output
# > Name: School Volvo Speed: 180 Mileage: 12
# ```

# %%
class Vehicle:
    def __init__(self, name, speed, mileage):
        self.name = name
        self.speed = speed
        self.mileage = mileage

class Bus(Vehicle):
    def __init__(self, name, speed, mileage):
        super().__init__(name, speed, mileage)

bus = Bus("School Volvo", 180, 12)
print(f"Name: {bus.name}, Speed: {bus.speed}, Mileage: {bus.mileage}")
# Out:
# Name: School Volvo, Speed: 180, Mileage: 12
